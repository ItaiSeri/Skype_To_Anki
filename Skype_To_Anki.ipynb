# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

import pandas as pd
import numpy as np
from pathlib import Path
from pandas.io.json import json_normalize

import googletrans
from googletrans import Translator

path=Path("F:\Dowloads\8_itai.seri_export/messages.json")
expath=Path("F:/Dowloads")

msg =pd.read_json(path) #output: DataFrame, all relavent data in 'conversations' column 
conver=msg.conversations #output: Series
norm=json_normalize(conver) #output: DataFrame, breaks up Series to DataFrame (with meaningfull columns)
########
an=norm.MessageList[norm.displayName=='Anne Wu']
an_df=pd.DataFrame(an[9])
#an_df.to_csv(expath/'conv.txt', header=None, index=None, mode='a')
############

multiple_df=norm.MessageList.apply(lambda x: pd.DataFrame(x))
df=pd.concat(multiple_df.tolist())
df.content.to_csv(expath/'conv.txt', header=None, index=None, mode='a')

translator = Translator()
#print (translator.translate('小伙子怎么了',src='zh-CN').text)
#print (translator.translate('hello world').src)



an_df['tr']=an_df.content.apply(lambda x: translator.translate(x))

#an_df['tr']=an_df.content.apply(lambda x: len(x))


print (an_df.content)


print ('done')
# Out:
# 0                                         see you soon !
# 1                                 yes yes. thank you !!!
# 2                                      see you next time
# 3               Sure, I think I understand what you mean
# 4                           and I think we need to adapt
# 5      i am not angry, just because we not in the sam...
# 6                                          I need to say
# 7                                                     hi
# 8      <partlist type="ended" alt="" callId="bd240041...
# 9                              don&apos;t afrain mistake
# 10                                                ז„₪ז€’
# 11     wַ’ qֳ¹ dֳ  chֳ©ng shֳ¬ de diֳ n yַ�ng yuֳ n k...
# 12                                xiֳ  chִ“ \nה¸‹  ט½¦
# 13     nַ� xiִ�n zuֳ² wַ” lֳ¹ chִ“ ן¼� rֳ¡n hֳ²u zhuַ...
# 14                           wַ” lֳ¹ chִ“ \nה÷” ט·¯ ט½¦
# 15     wַ’ yִ«ng gִ�i zuֳ² nַ� lֳ¹ chִ“ ן¼� \nזˆ‘ ו÷”...
# 16     wַ’ zֳ i nַ� gֳ¨ zhֳ n xiֳ  chִ“ ן¼� \nזˆ‘ ו�¨...
# 17     zhֳ¨ ֳ©r fֳ¹ jֳ¬n yַ’u chִ“ zhֳ n ma ן¼� \nט¿™...
# 18     zuֳ² gֵ�ng gֳ²ng qֳ¬ chִ“ \nו��  ו…¬   ו…±   ז...
# 19               qֳ­ zֳ¬ xֳ­ng chִ“ \nי×‘ ט‡× ט¡�   ט½¦
# 20     wַ’ chֳ¡ng chֳ¡ng zuֳ² dֳ¬ tiִ› chֵ« qu ד€‚ \n...
# 21                         zuֳ² dֳ¬ tiִ› \nו��  ו�° י“�
# 22                       zuֳ² huַ’ chִ“ \nו��  ח�«  ט½¦
# 23     wַ’ zuֳ² fִ“i jִ« qֳ¹ zhֵ�ng guֳ³ ד€‚ \nזˆ‘ ו�...
# 24                        zuֳ² fִ“i jִ« \nו��  י£�  ז�÷
# 25                                              by plane
# 26                                            take plane
# 27                     wַ�ng huֳ­ zַ’u \nו¾€   ו›�  טµ°
# 28     <URIObject uri="https://api.asm.skype.com/v1/o...
# 29     nַ� xiִ�n yֳ¬ zhֳ­ zַ’u ן¼� rֳ¡n hֳ²u zֳ i dֳ¬...
#                              ...
# 103         chֳ¡ \nט�¶  \nyֳ¬ bִ“i chֳ¡ \nה¸€ ז�¯  ט�¶
# 104    <URIObject uri="https://api.asm.skype.com/v1/o...
# 105    <URIObject uri="https://api.asm.skype.com/v1/o...
# 106    wַ’ yֳ o mֳ³ gu xiֳ nr de ד€‚ \nזˆ‘ ט¦�  ט˜‘ ט...
# 107    nַ� yֳ o shֳ©n me xiֳ nr de bִ�o zi ן¼� \nה½  ...
# 108                                  xiֳ nr \nי¦…   ו„¿
# 109    bִ�o zi \nו�…  ו­� \nyֳ¬ lֳ³ng bִ�o zi \nה¸€ ח...
# 110    <URIObject uri="https://api.asm.skype.com/v1/o...
# 111    nַ� yֳ o dֳ  wַ�n hֳ¡i shֳ¬ xiַ�o wַ�n ן¼� \nה...
# 112      miֳ n \nי�¢   \nyֳ¬ wַ�n miֳ n \nה¸€ ח¢—  י�¢
# 113    <URIObject uri="https://api.asm.skype.com/v1/o...
# 114               yֳ¬ wַ�n mַ� fֳ n \nה¸€ ח¢—  ח±³ י¥­
# 115                                 mַ� fֳ n \nח±³ י¥­
# 116    <URIObject uri="https://api.asm.skype.com/v1/o...
# 117    qַ�ng lֳ¡i yֳ¬ pֳ¡n jiַ�o zi ד€‚ \nט¯·   ז�¥  ...
# 118              yֳ¬ pֳ¡n jiַ�o zi \nה¸€ ח›˜  י¥÷   ו­�
# 119                                 jiַ�o zi \nי¥÷   ו­�
# 120    <URIObject uri="https://api.asm.skype.com/v1/o...
# 121    wַ’ hֳ¡i mֳ©i shֳ¬ guֳ² zhֵ�ng guֳ³ cֳ i ד€‚ \...
# 122                             diַ�n cֳ i \nח‚¹   ט��
# 123    xiֳ  kֳ¨ hֳ²u wַ’ kִ�i shַ� gֵ�ng zuֳ² ד€‚ \nה...
# 124    <partlist type="started" alt="" callId="c541f2...
# 125    <partlist type="ended" alt="" callId="f125a861...
# 126    zַ�o shang jiַ” diַ�n sֳ¬ shֳ­ \nז—©  ה¸�    ה...
# 127                 chֳ©ng xֳ¹ yuֳ¡n \nח¨‹    ו÷� ו‘˜
# 128    <partlist type="started" alt="" callId="f125a8...
# 129                                  Ready when your are
# 130    ה½ ו¥½<ss type="ok">(ok)</ss><ss type="ok">(ok...
# 131                                     Anne from italki
# 132                            <ss type="hi">(wave)</ss>
# Name: content, Length: 133, dtype: object
# done

# %%
an_df.content
# Out:
# 0                                         see you soon !
# 1                                 yes yes. thank you !!!
# 2                                      see you next time
# 3               Sure, I think I understand what you mean
# 4                           and I think we need to adapt
# 5      i am not angry, just because we not in the sam...
# 6                                          I need to say
# 7                                                     hi
# 8      <partlist type="ended" alt="" callId="bd240041...
# 9                              don&apos;t afrain mistake
# 10                                                ז„₪ז€’
# 11     wַ’ qֳ¹ dֳ  chֳ©ng shֳ¬ de diֳ n yַ�ng yuֳ n k...
# 12                                xiֳ  chִ“ \nה¸‹  ט½¦
# 13     nַ� xiִ�n zuֳ² wַ” lֳ¹ chִ“ ן¼� rֳ¡n hֳ²u zhuַ...
# 14                           wַ” lֳ¹ chִ“ \nה÷” ט·¯ ט½¦
# 15     wַ’ yִ«ng gִ�i zuֳ² nַ� lֳ¹ chִ“ ן¼� \nזˆ‘ ו÷”...
# 16     wַ’ zֳ i nַ� gֳ¨ zhֳ n xiֳ  chִ“ ן¼� \nזˆ‘ ו�¨...
# 17     zhֳ¨ ֳ©r fֳ¹ jֳ¬n yַ’u chִ“ zhֳ n ma ן¼� \nט¿™...
# 18     zuֳ² gֵ�ng gֳ²ng qֳ¬ chִ“ \nו��  ו…¬   ו…±   ז...
# 19               qֳ­ zֳ¬ xֳ­ng chִ“ \nי×‘ ט‡× ט¡�   ט½¦
# 20     wַ’ chֳ¡ng chֳ¡ng zuֳ² dֳ¬ tiִ› chֵ« qu ד€‚ \n...
# 21                         zuֳ² dֳ¬ tiִ› \nו��  ו�° י“�
# 22                       zuֳ² huַ’ chִ“ \nו��  ח�«  ט½¦
# 23     wַ’ zuֳ² fִ“i jִ« qֳ¹ zhֵ�ng guֳ³ ד€‚ \nזˆ‘ ו�...
# 24                        zuֳ² fִ“i jִ« \nו��  י£�  ז�÷
# 25                                              by plane
# 26                                            take plane
# 27                     wַ�ng huֳ­ zַ’u \nו¾€   ו›�  טµ°
# 28     <URIObject uri="https://api.asm.skype.com/v1/o...
# 29     nַ� xiִ�n yֳ¬ zhֳ­ zַ’u ן¼� rֳ¡n hֳ²u zֳ i dֳ¬...
#                              ...
# 103         chֳ¡ \nט�¶  \nyֳ¬ bִ“i chֳ¡ \nה¸€ ז�¯  ט�¶
# 104    <URIObject uri="https://api.asm.skype.com/v1/o...
# 105    <URIObject uri="https://api.asm.skype.com/v1/o...
# 106    wַ’ yֳ o mֳ³ gu xiֳ nr de ד€‚ \nזˆ‘ ט¦�  ט˜‘ ט...
# 107    nַ� yֳ o shֳ©n me xiֳ nr de bִ�o zi ן¼� \nה½  ...
# 108                                  xiֳ nr \nי¦…   ו„¿
# 109    bִ�o zi \nו�…  ו­� \nyֳ¬ lֳ³ng bִ�o zi \nה¸€ ח...
# 110    <URIObject uri="https://api.asm.skype.com/v1/o...
# 111    nַ� yֳ o dֳ  wַ�n hֳ¡i shֳ¬ xiַ�o wַ�n ן¼� \nה...
# 112      miֳ n \nי�¢   \nyֳ¬ wַ�n miֳ n \nה¸€ ח¢—  י�¢
# 113    <URIObject uri="https://api.asm.skype.com/v1/o...
# 114               yֳ¬ wַ�n mַ� fֳ n \nה¸€ ח¢—  ח±³ י¥­
# 115                                 mַ� fֳ n \nח±³ י¥­
# 116    <URIObject uri="https://api.asm.skype.com/v1/o...
# 117    qַ�ng lֳ¡i yֳ¬ pֳ¡n jiַ�o zi ד€‚ \nט¯·   ז�¥  ...
# 118              yֳ¬ pֳ¡n jiַ�o zi \nה¸€ ח›˜  י¥÷   ו­�
# 119                                 jiַ�o zi \nי¥÷   ו­�
# 120    <URIObject uri="https://api.asm.skype.com/v1/o...
# 121    wַ’ hֳ¡i mֳ©i shֳ¬ guֳ² zhֵ�ng guֳ³ cֳ i ד€‚ \...
# 122                             diַ�n cֳ i \nח‚¹   ט��
# 123    xiֳ  kֳ¨ hֳ²u wַ’ kִ�i shַ� gֵ�ng zuֳ² ד€‚ \nה...
# 124    <partlist type="started" alt="" callId="c541f2...
# 125    <partlist type="ended" alt="" callId="f125a861...
# 126    zַ�o shang jiַ” diַ�n sֳ¬ shֳ­ \nז—©  ה¸�    ה...
# 127                 chֳ©ng xֳ¹ yuֳ¡n \nח¨‹    ו÷� ו‘˜
# 128    <partlist type="started" alt="" callId="f125a8...
# 129                                  Ready when your are
# 130    ה½ ו¥½<ss type="ok">(ok)</ss><ss type="ok">(ok...
# 131                                     Anne from italki
# 132                            <ss type="hi">(wave)</ss>
# Name: content, Length: 133, dtype: object
